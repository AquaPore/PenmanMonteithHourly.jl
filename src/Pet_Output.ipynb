# %%
using Dates

Date = Dates.Date(2013,12,31)

 Dates.dayofyear(Date)
# Out:
# 365

# %%
		DayOfYear = 1
		Hour = 8
		b = 2* π * (DayOfYear - 81) /364

		Sc = 0.1645 * sin(2*b) - 0.1255 * cos(b) - 0.025 * sin(b)

		ωₛ_SOLAR_TIME_ANGLE(Hour, Sc) = ((Hour + Sc ) -12.0) * π / 12.0

		W1 = ωₛ_SOLAR_TIME_ANGLE(Hour, Sc)
# Out:
# -1.0629355049617244

# %%
using SolarPosition

obs = SolarPosition.Observer(51.5, -0.09, 100.0)
times = (DateTime(2023, 1, 1, 8))

positions = solar_position(obs, times)

# 36.26338495
770448 * pi / 180
# Out:
# SolPos(azimuth=126.4113940402111°, elevation=-1.5812997085223703°, zenith=91.58129970852237°)

# %%
dms"1°2′3″"deg
# Out:
# LoadError: UndefVarError: `@dms_str` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
# in expression starting at d:\JOE\MAIN\MODELS\PET\src\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:1
#
#
#
# Stacktrace:
#
#  [1] eval(m::Module, e::Any)
#
#    @ Core .\boot.jl:489
#
#  [2] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#    @ Base .\loading.jl:2870
#
#  [3] (::VSCodeServer.var"#notebook_runcell_request##0#notebook_runcell_request##1"{VSCodeServer.NotebookRunCellArguments, String})()
#
#    @ VSCodeServer c:\Users\jpollacco.local\.vscode\extensions\julialang.language-julia-1.176.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#
#  [4] withpath(f::VSCodeServer.var"#notebook_runcell_request##0#notebook_runcell_request##1"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
# ...
